# %%
import requests 
import json 



#Get all active tokens after loggin in API 
def get_active_token():  
    start_url = "http://www.newsedge.com/opensapi/20/session/getactivesessions?name=mick.endsor@digital-insight.com&password=a9f78da238685fc57286df70440727a0"
    response = requests.get(start_url)
    response.content
    return response 

#print(type(log_in().content.decode(encoding='utf-8', errors='strict')))
#When get_active was call log_in ^ 
#print(log_in().content.decode(encoding='utf-8', errors='strict')[116:148])

token = get_active_token().content.decode(encoding='utf-8', errors='strict')[116:148]

print(token)
# Out:
# B63ABAF48F26787E75183D16B3A39AC4

# %%
help(bytes)
# Out:
# Help on class bytes in module builtins:
#
# class bytes(object)
#  |  bytes(iterable_of_ints) -> bytes
#  |  bytes(string, encoding[, errors]) -> bytes
#  |  bytes(bytes_or_buffer) -> immutable copy of bytes_or_buffer
#  |  bytes(int) -> bytes object of size given by the parameter initialized with null bytes
#  |  bytes() -> empty bytes object
#  |
#  |  Construct an immutable array of bytes from:
#  |    - an iterable yielding integers in range(256)
#  |    - a text string encoded using the specified encoding
#  |    - any object implementing the buffer API.
#  |    - an integer
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
# ...

# %%
#api list
print((requests.get("http://www.newsedge.com/opensapi/20/api/list?session=" + token)).content.decode('utf-8'))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <opens-api>
# <status>OK</status>
# <api-list>
# <api>
# <name>api/info</name>
# <desc></desc>
# </api>
# <api>
# <name>api/list</name>
# <desc></desc>
# </api>
# <api>
# <name>company/search</name>
# <desc></desc>
# </api>
# <api>
# <name>dictionary/search</name>
# <desc></desc>
# </api>
# <api>
# <name>geography/search</name>
# <desc></desc>
# </api>
# <api>
# <name>industry/search</name>
# <desc></desc>
# </api>
# <api>
# <name>media/read</name>
# <desc></desc>
# </api>
# <api>
# <name>news/read</name>
# <desc></desc>
# </api>
# <api>
# <name>news/search</name>
# <desc></desc>
# </api>
# <api>
# <name>people/search</name>
# <desc></desc>
# </api>
# <api>
# <name>savedsearch/info</name>
# <desc></desc>
# </api>
# <api>
# <name>savedsearch/list</name>
# <desc></desc>
# </api>
# <api>
# <name>session/clearsessions</name>
# <desc></desc>
# </api>
# <api>
# <name>session/getactivesessions</name>
# <desc></desc>
# </api>
# <api>
# ...

# %%
#company Search
#to find Acorn#( news search number for company)
print(requests.get("http://www.newsedge.com/opensapi/20/company/search?session="+token+"&query=(TopShop)").content.decode('utf8'))

#print(type(requests.get("http://www.newsedge.com/opensapi/20/company/search?session="+token+"&query=(TopShop)").content.decode('utf8')))
# Out:
# <?xml version="1.0" encoding="UTF-8"?><entity-list totalHits="1"><entity tickers="1"><name>Topshop</name><short-name>Topshop</short-name><acorn>6000176416</acorn><ultacorn>0307820244</ultacorn><docfreq>6454</docfreq><ticker><symbol>6000176416</symbol><amstel>EQUITY</amstel><exchange-name>Private</exchange-name><exchange-country>US</exchange-country></ticker><parent more-children="true"><acorn>0307820244</acorn><name>Taveta Ltd</name></parent></entity>
# </entity-list>

# %%
#Search for barclays in headline 
#http://www.newsedge.com/opensapi/20/news/search?session=B522F74B2D2477A0A1B1FBD0951B0032&query=({Barclays}.location=headline)

#People search(bill gates)
#http://www.newsedge.com/opensapi/20/people/search?session=29879CA16CC5F125BC5D4CD454AD2942&query=("bill gates
#")&awesome=1
